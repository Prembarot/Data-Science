# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
exp_vals = [1400,600,300,410,250]
exp_lables = ["Home Rent","Food","Phone/ Internet Bill","Car","Other Utlities"]
plt.pie(exp_vals, labels = exp_lables,explode=[0,0,0,0.2,0.2])
plt.show()
