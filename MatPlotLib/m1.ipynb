# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.9.2

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array([0,6,15])
y=np.array([0,250,100])
plt.plot(x,y)
plt.show()
