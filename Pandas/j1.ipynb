# %%
import pandas as pd
import numpy as np
weather_data = {
    'day' : ['1/5/2024','5/4/2025','6/2/2023','5/5/2028','7/10/2025','3/5/2029'],
    'temperature' : [32,35,28,24,27,41],
    'windspeed' : [6,8,7,2,1,5],
    'event' : ['rain','sunny','snow','snow','rain','sunny']
}

# %%
#1) Create a Dataframe
df = pd.DataFrame(weather_data)
print(df)
# Out:
#          day  temperature  windspeed  event
# 0   1/5/2024           32          6   rain
# 1   5/4/2025           35          8  sunny
# 2   6/2/2023           28          7   snow
# 3   5/5/2028           24          2   snow
# 4  7/10/2025           27          1   rain
# 5   3/5/2029           41          5  sunny

# %%
#2) Print Shape
df.shape
# Out:
# (6, 4)

# %%
r,c = df.shape
print(r)
print(c)
# Out:
# 6
# 4

# %%
#4) print first five records
df.head()
# Out:
#          day  temperature  windspeed  event
# 0   1/5/2024           32          6   rain
# 1   5/4/2025           35          8  sunny
# 2   6/2/2023           28          7   snow
# 3   5/5/2028           24          2   snow
# 4  7/10/2025           27          1   rain

# %%
#5) print last five records
df.tail()
# Out:
#          day  temperature  windspeed  event
# 1   5/4/2025           35          8  sunny
# 2   6/2/2023           28          7   snow
# 3   5/5/2028           24          2   snow
# 4  7/10/2025           27          1   rain
# 5   3/5/2029           41          5  sunny

# %%
#4) print first two records
df.head(2)
# Out:
#         day  temperature  windspeed  event
# 0  1/5/2024           32          6   rain
# 1  5/4/2025           35          8  sunny

# %%
#5) print last three records
df.tail(3)
# Out:
#          day  temperature  windspeed  event
# 3   5/5/2028           24          2   snow
# 4  7/10/2025           27          1   rain
# 5   3/5/2029           41          5  sunny

# %%
#6) print row : 2 to row : 4
df.iloc[2:4]
# Out:
#         day  temperature  windspeed event
# 2  6/2/2023           28          7  snow
# 3  5/5/2028           24          2  snow

# %%
#7) print name of columns
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
#8) print maximum temperature
df['temperature'].max()
# Out:
# 41

# %%
#9) print minimum temperature
df['temperature'].min()
# Out:
# 24

# %%
#10) print average temperature
df['temperature'].mean()
# Out:
# 31.166666666666668

# %%
#11) use df.describe() command
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     31.166667   4.833333
# std       6.177918   2.786874
# min      24.000000   1.000000
# 25%      27.250000   2.750000
# 50%      30.000000   5.500000
# 75%      34.250000   6.750000
# max      41.000000   8.000000

# %%
#12) print records for temperature gr. th. 32
df[df['temperature']>32]
# Out:
#         day  temperature  windspeed  event
# 1  5/4/2025           35          8  sunny
# 5  3/5/2029           41          5  sunny

# %%
#13) print record for max. temperature
df[df['temperature'] == df['temperature'].max()]
# Out:
#         day  temperature  windspeed  event
# 5  3/5/2029           41          5  sunny

# %%
#14) displaying date when max temp 
df['day'][df.temperature == df.temperature.max()]
# Out:
# 5    3/5/2029
# Name: day, dtype: object

# %%
df[['day','windspeed','temperature']][df.temperature == df.temperature.max()]
# Out:
#         day  windspeed  temperature
# 5  3/5/2029          5           41

# %%
#15) change index column to event
df.set_index('event',inplace=True)
df
# Out:
#              day  temperature  windspeed
# event
# rain    1/5/2024           32          6
# sunny   5/4/2025           35          8
# snow    6/2/2023           28          7
# snow    5/5/2028           24          2
# rain   7/10/2025           27          1
# sunny   3/5/2029           41          5

# %%
#16) reset index column as index column
df.reset_index(inplace=True)
df
# Out:
#    level_0  index  event        day  temperature  windspeed
# 0        0      0   rain   1/5/2024           32          6
# 1        1      1  sunny   5/4/2025           35          8
# 2        2      2   snow   6/2/2023           28          7
# 3        3      3   snow   5/5/2028           24          2
# 4        4      4   rain  7/10/2025           27          1
# 5        5      5  sunny   3/5/2029           41          5
